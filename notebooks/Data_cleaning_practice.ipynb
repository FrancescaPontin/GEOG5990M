# %%
# read in pandas package
import pandas as pd

# %%
# read in listings data
# note the relative filepath to where the data is stored.
# You might need to change your file path to point to where your data is saved
listings  =pd.read_csv('../data/week_16/listings.csv')

# # comment the line above and uncomment to read file into colab directly from github:
# listings  =pd.read_csv('https://raw.githubusercontent.com/FrancescaPontin/GEOG5990M/refs/heads/main/data/week_16/listings.csv')

# %% [markdown]
# Learn more about relative filepaths [here](https://www.lenovo.com/gb/en/glossary/relative-path/?orgRef=https%253A%252F%252Fwww.google.com%252F&srsltid=AfmBOoqBb9DfD-BIfV3FlkRjimzXzdOff9ZLTgoMZZALvHIqDYuQWTan)

# %%
# have a look at data frame
listings.head()

# %%
# initial check for missing data
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4936 entries, 0 to 4935
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              4936 non-null   int64
#  1   name                            4936 non-null   object
#  2   host_id                         4936 non-null   int64
#  3   host_name                       4934 non-null   object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   4936 non-null   object
#  6   latitude                        4936 non-null   float64
#  7   longitude                       4936 non-null   float64
#  8   room_type                       4936 non-null   object
#  9   price                           4925 non-null   float64
#  10  minimum_nights                  4936 non-null   int64
#  11  number_of_reviews               4936 non-null   int64
# ...

# %% [markdown]
# ## Tasks
# Have a go at cleaning the listings dataset.
# Think about what data is missing and why.
# How you address the missing data may vary via scenario:
# - Scenario 1: You own a 3-bed house in the South Leith Area of Edinburgh and want to rent it out via Airbnb and competitively price your listing.
# - Scenario 2: You work for Edinburgh council and you want to identify priority areas in the city to inspect for unlicensed airbnbs
# How might we handle the missing data in each of the above scenarios?
#
# (After next week you may want to come back to your saved .ipynb and use data visualisation to support your decision making)

# %%
# write your own code
